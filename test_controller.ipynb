# %%
# test_controller.ipynb

# Add the directory containing your modules to the system path
sys.path.append(os.path.abspath('.'))

# Import necessary classes from your project
from mission import Mission
from submarine import Submarine
from closed_loop import ClosedLoop
from control import PDController

print("Starting the simulation...")

# Generate a random mission or load from CSV (if you have implemented the from_csv method)
# Example: mission = Mission.from_csv('/Users/jelenazlataric/Desktop/ENGINEERING SCIENCE/B1 practical 1/b1-coding-practical-mt24/data/mission.csv)
mission = Mission.random_mission(duration=10, scale=1.0)

# Create instances of Submarine and PDController
submarine = Submarine()
print("Submarine created.")
controller = PDController(kp=0.15, kd=0.6)
print("Controller initialized.")

# Create a ClosedLoop system with the submarine and controller
closed_loop = ClosedLoop(submarine=submarine, controller=controller)
print("Closed loop system initialized.")

# Simulate the system with random disturbances and visualize the results
trajectory = closed_loop.simulate_with_random_disturbances(mission, variance=0.5)
print("Simulation completed.")

# Plot the resulting trajectory against the mission profile
trajectory.plot_completed_mission(mission)
print("Plotting complete.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 9
#       6 sys.path.append(os.path.abspath('.'))
#       8 # Import necessary classes from your project
# ----> 9 from mission import Mission
#      10 from submarine import Submarine
#      11 from closed_loop import ClosedLoop
#
# ModuleNotFoundError: No module named 'mission'

# %%
# test_controller.ipynb

# Import necessary libraries
import sys
import os

# Add the directory containing your modules to the system path
sys.path.append(os.path.abspath('.'))

# Import necessary classes from your project
from mission import Mission
from submarine import Submarine
from closed_loop import ClosedLoop
from control import PDController

print("Starting the simulation...")

# Generate a random mission or load from CSV (if you have implemented the from_csv method)
# Make sure the path is correct if using an absolute path
mission = Mission.random_mission(duration=10, scale=1.0)

# Create instances of Submarine and PDController
submarine = Submarine()
print("Submarine created.")
controller = PDController(kp=0.15, kd=0.6)
print("Controller initialized.")

# Create a ClosedLoop system with the submarine and controller
closed_loop = ClosedLoop(submarine=submarine, controller=controller)
print("Closed loop system initialized.")

# Simulate the system with random disturbances and visualize the results
trajectory = closed_loop.simulate_with_random_disturbances(mission, variance=0.5)
print("Simulation completed.")

# Plot the resulting trajectory against the mission profile
trajectory.plot_completed_mission(mission)
print("Plotting complete.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 11
#       8 sys.path.append(os.path.abspath('.'))
#      10 # Import necessary classes from your project
# ---> 11 from mission import Mission
#      12 from submarine import Submarine
#      13 from closed_loop import ClosedLoop
#
# ModuleNotFoundError: No module named 'mission'

# %%
# test_controller.ipynb

# Import necessary libraries
import sys
import os

# Add the directory containing your modules to the system path
sys.path.append(os.path.abspath('./data'))
sys.path.append(os.path.abspath('./uuv_mission'))

# Import necessary classes from your project
from dynamic import Mission
from dynamic import Submarine
from dynamic import ClosedLoop
from control import PDController

print("Starting the simulation...")

# Generate a random mission or load from CSV (if you have implemented the from_csv method)
#mission = Mission.from_csv('/Users/jelenazlataric/Desktop/ENGINEERING SCIENCE/B1 practical 1/b1-coding-practical-mt24/data/mission.csv')
mission = Mission.random_mission(duration=100, scale=1.0)

# Create instances of Submarine and PDController
submarine = Submarine()
print("Submarine created.")
controller = PDController(kp=0.15, kd=0.6)
print("Controller initialized.")

# Create a ClosedLoop system with the submarine and controller
closed_loop = ClosedLoop(plant=submarine, controller=controller)
print("Closed loop system initialized.")

# Simulate the system with random disturbances and visualize the results
trajectory = closed_loop.simulate_with_random_disturbances(mission, variance=0.5)
print("Simulation completed.")

# Plot the resulting trajectory against the mission profile
trajectory.plot_completed_mission(mission)
print("Plotting complete.")
# Out:
# Starting the simulation...
# Submarine created.
# Controller initialized.
# Closed loop system initialized.
# Simulation completed.
# Plotting complete.
